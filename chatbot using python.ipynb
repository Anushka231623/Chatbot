# %%
import re
import random

# Define some pattern-response pairs for the chatbot
patterns = [
    (r'hi|hello|hey', ['Hello!', 'Hi there!', 'Hey!', 'Hi! How can I help you?']),
    (r'how are you\?', ['I am doing well, thank you!', 'I am fine, thanks for asking!', 'All good!']),
    (r'what is your name\?', ['I am a chatbot!', 'I am a virtual assistant!', 'You can call me ChatBot.']),
    (r'your name?', ['You can call me ChatBot.']),
    (r'weather', ['The weather is nice today.', 'It is sunny outside.']),
    (r'temperature', ['The temperature is 72°F.', 'It is warm today.']),
    (r'help', ['Sure, I can help you with that.', 'What do you need help with?']),
    (r'bye|goodbye', ['Goodbye!', 'Bye!', 'Take care!']),

    # Add stock market related questions
    (r'what is the current price of (.*)\?', ['The current price of {} is $XX.XX.', 'The price of {} is $XX.XX.']),
    (r'how is the stock market doing today(.*)\?', ['The stock market is up/down today.', 'Today, the stock market is performing well/poorly.']),
    (r'what is the price-to-earnings ratio of (.*)\?', ['The price-to-earnings ratio of {} is XX.XX.', 'The P/E ratio of {} is XX.XX.']),
    (r'give me some information about (.*) stock\?', ['Sure, here is some information about {} stock...', 'Let me find some information about {} stock...']),
    (r'what is the market capitalization of (.*)\?', ['The market capitalization of {} is $XX.XX billion.', '{} has a market capitalization of $XX.XX billion.']),
    (r'what is the dividend yield of (.*)\?', ['The dividend yield of {} is XX%.', '{} has a dividend yield of XX%.']),
    (r'what is the 52-week high of (.*)\?', ['The 52-week high of {} is $XX.XX.', '{} reached a 52-week high of $XX.XX.']),
    (r'what is the 52-week low of (.*)\?', ['The 52-week low of {} is $XX.XX.', '{} reached a 52-week low of $XX.XX.']),
    (r'what is the volume of (.*)\?', ['The volume of {} is XX.', '{} has a volume of XX.']),
    (r'what is the earnings per share of (.*)\?', ['The earnings per share of {} is $XX.XX.', '{} has an earnings per share of $XX.XX.']),
    (r'what is the forward P/E ratio of (.*)\?', ['The forward P/E ratio of {} is XX.XX.', '{} has a forward P/E ratio of XX.XX.']),
    (r'what is the earnings growth rate of (.*)\?', ['The earnings growth rate of {} is XX%.', '{} has an earnings growth rate of XX%.']),
    (r'what is the debt-to-equity ratio of (.*)\?', ['The debt-to-equity ratio of {} is XX.', '{} has a debt-to-equity ratio of XX.']),
    (r'what is the return on equity of (.*)\?', ['The return on equity of {} is XX%.', '{} has a return on equity of XX%.']),
    (r'what is the beta of (.*)\?', ['The beta of {} is XX.', '{} has a beta of XX.']),
    (r'what is the average trading volume of (.*)\?', ['The average trading volume of {} is XX.', '{} has an average trading volume of XX.']),
    (r'what is the analyst rating of (.*)\?', ['The analyst rating of {} is XX.', '{} has an analyst rating of XX.']),
    (r'what is the price change percentage of (.*)\?', ['The price change percentage of {} is XX%.', '{} has a price change percentage of XX%.']),
    (r'what is the dividend payout ratio of (.*)\?', ['The dividend payout ratio of {} is XX%.', '{} has a dividend payout ratio of XX%.']),
    (r'what is the current ratio of (.*)\?', ['The current ratio of {} is XX.', '{} has a current ratio of XX.']),
    (r'what is the quick ratio of (.*)\?', ['The quick ratio of {} is XX.', '{} has a quick ratio of XX.']),
    (r'what is the price-to-book ratio of (.*)\?', ['The price-to-book ratio of {} is XX.', '{} has a price-to-book ratio of XX.']),
    (r'what is the dividend growth rate of (.*)\?', ['The dividend growth rate of {} is XX%.', '{} has a dividend growth rate of XX%.']),
    (r'what is the debt ratio of (.*)\?', ['The debt ratio of {} is XX%.', '{} has a debt ratio of XX%.']),
    (r'what is the asset turnover ratio of (.*)\?', ['The asset turnover ratio of {} is XX.', '{} has an asset turnover ratio of XX.']),
    (r'what is the profit margin of (.*)\?', ['The profit margin of {} is XX%.', '{} has a profit margin of XX%.']),
    (r'what is the operating margin of (.*)\?', ['The operating margin of {} is XX%.', '{} has an operating margin of XX%.']),
    (r'what is the free cash flow of (.*)\?', ['The free cash flow of {} is $XX.XX million.', '{} has a free cash flow of $XX.XX million.']),
    (r'what is the price-to-sales ratio of (.*)\?', ['The price-to-sales ratio of {} is XX.', '{} has a price-to-sales ratio of XX.']),
    (r'what is the return on assets of (.*)\?', ['The return on assets of {} is XX%.', '{} has a return on assets of XX%.']),
    (r'what is the return on investment of (.*)\?', ['The return on investment of {} is XX%.', '{} has a return on investment of XX%.']),


]

# Define a function to respond to the user input
def respond(user_input):
    for pattern, responses in patterns:
        match = re.search(pattern, user_input.strip(), re.IGNORECASE)
        if match:
            response = random.choice(responses)
            return response.format(*match.groups())

    # If no pattern matched, return a default response
    return "I'm sorry, I'm not sure how to respond to that."

# Define a function to start and interact with the chatbot
def start_chat():
    print("Hello! I am a simple chatbot. You can start chatting with me. Type 'quit' to exit.")
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'quit':
            print("Goodbye!")
            break
        response = respond(user_input)
        print("ChatBot:", response)

# Start the chat
start_chat()
# Out:
# Hello! I am a simple chatbot. You can start chatting with me. Type 'quit' to exit.

# %%
import tkinter as tk
from tkinter import scrolledtext
from PIL import Image, ImageTk
import random
import re

# Define some pattern-response pairs for the chatbot
patterns = [
    (r'hi|hello|hey', ['Hello!', 'Hi there!', 'Hey!', 'Hi! How can I help you?']),
    (r'how are you\?', ['I am doing well, thank you!', 'I am fine, thanks for asking!', 'All good!']),
    (r'what is your name\?', ['I am a chatbot!', 'I am a virtual assistant!', 'You can call me ChatBot.']),
    (r'(.*) your name\?', ['You can call me ChatBot.']),
    (r'weather', ['The weather is nice today.', 'It is sunny outside.']),
    (r'temperature', ['The temperature is 72°F.', 'It is warm today.']),
    (r'(.) help (.)', ['Sure, I can help you with that.', 'What do you need help with?']),
    (r'bye|goodbye', ['Goodbye!', 'Bye!', 'Take care!']),

    # Add stock market related questions
    (r'what is the current price of (.*)\?', ['The current price of {} is $XX.XX.', 'The price of {} is $XX.XX.']),
    (r'how is the stock market doing today(.*)\?', ['The stock market is up/down today.', 'Today, the stock market is performing well/poorly.']),
    (r'what is the price-to-earnings ratio of (.*)\?', ['The price-to-earnings ratio of {} is XX.XX.', 'The P/E ratio of {} is XX.XX.']),
    (r'give me some information about (.*) stock\?', ['Sure, here is some information about {} stock...', 'Let me find some information about {} stock...']),
    (r'what is the market capitalization of (.*)\?', ['The market capitalization of {} is $XX.XX billion.', '{} has a market capitalization of $XX.XX billion.']),
    (r'what is the dividend yield of (.*)\?', ['The dividend yield of {} is XX%.', '{} has a dividend yield of XX%.']),
    (r'what is the 52-week high of (.*)\?', ['The 52-week high of {} is $XX.XX.', '{} reached a 52-week high of $XX.XX.']),
    (r'what is the 52-week low of (.*)\?', ['The 52-week low of {} is $XX.XX.', '{} reached a 52-week low of $XX.XX.']),
    (r'what is the volume of (.*)\?', ['The volume of {} is XX.', '{} has a volume of XX.']),
    (r'what is the earnings per share of (.*)\?', ['The earnings per share of {} is $XX.XX.', '{} has an earnings per share of $XX.XX.']),
    (r'what is the forward P/E ratio of (.*)\?', ['The forward P/E ratio of {} is XX.XX.', '{} has a forward P/E ratio of XX.XX.']),
    (r'what is the earnings growth rate of (.*)\?', ['The earnings growth rate of {} is XX%.', '{} has an earnings growth rate of XX%.']),
    (r'what is the debt-to-equity ratio of (.*)\?', ['The debt-to-equity ratio of {} is XX.', '{} has a debt-to-equity ratio of XX.']),
    (r'what is the return on equity of (.*)\?', ['The return on equity of {} is XX%.', '{} has a return on equity of XX%.']),
    (r'what is the beta of (.*)\?', ['The beta of {} is XX.', '{} has a beta of XX.']),
    (r'what is the average trading volume of (.*)\?', ['The average trading volume of {} is XX.', '{} has an average trading volume of XX.']),
    (r'what is the analyst rating of (.*)\?', ['The analyst rating of {} is XX.', '{} has an analyst rating of XX.']),
    (r'what is the price change percentage of (.*)\?', ['The price change percentage of {} is XX%.', '{} has a price change percentage of XX%.']),
    (r'what is the dividend payout ratio of (.*)\?', ['The dividend payout ratio of {} is XX%.', '{} has a dividend payout ratio of XX%.']),
    (r'what is the current ratio of (.*)\?', ['The current ratio of {} is XX.', '{} has a current ratio of XX.']),
    (r'what is the quick ratio of (.*)\?', ['The quick ratio of {} is XX.', '{} has a quick ratio of XX.']),
    (r'what is the price-to-book ratio of (.*)\?', ['The price-to-book ratio of {} is XX.', '{} has a price-to-book ratio of XX.']),
    (r'what is the dividend growth rate of (.*)\?', ['The dividend growth rate of {} is XX%.', '{} has a dividend growth rate of XX%.']),
    (r'what is the debt ratio of (.*)\?', ['The debt ratio of {} is XX%.', '{} has a debt ratio of XX%.']),
    (r'what is the asset turnover ratio of (.*)\?', ['The asset turnover ratio of {} is XX.', '{} has an asset turnover ratio of XX.']),
    (r'what is the profit margin of (.*)\?', ['The profit margin of {} is XX%.', '{} has a profit margin of XX%.']),
    (r'what is the operating margin of (.*)\?', ['The operating margin of {} is XX%.', '{} has an operating margin of XX%.']),
    (r'what is the free cash flow of (.*)\?', ['The free cash flow of {} is $XX.XX million.', '{} has a free cash flow of $XX.XX million.']),
    (r'what is the price-to-sales ratio of (.*)\?', ['The price-to-sales ratio of {} is XX.', '{} has a price-to-sales ratio of XX.']),
    (r'what is the return on assets of (.*)\?', ['The return on assets of {} is XX%.', '{} has a return on assets of XX%.']),
    (r'what is the return on investment of (.*)\?', ['The return on investment of {} is XX%.', '{} has a return on investment of XX%.']),

]

# Define a function to respond to the user input
def respond(user_input):
    for pattern, responses in patterns:
        match = re.search(pattern, user_input.strip(), re.IGNORECASE)
        if match:
            response = random.choice(responses)
            return response.format(*match.groups())

    # If no pattern matched, return a default response
    return "I'm sorry, I'm not sure how to respond to that."

# Define a function to handle the user's input from the GUI
def send_message():
    user_input = entry.get()
    response = respond(user_input)
    chat_history.config(state=tk.NORMAL)
    chat_history.insert(tk.END, "You: " + user_input + "\n", "user")
    chat_history.insert(tk.END, "ChatBot: " + response + "\n", "bot")
    chat_history.config(state=tk.DISABLED)
    entry.delete(0, tk.END)

def clear_response():
    chat_history.config(state=tk.NORMAL)
    chat_history.delete(1.0, tk.END)
    chat_history.config(state=tk.DISABLED)

def chat_me():
    # Define your functionality for the "ChatMe" button here
    pass

# Create the main window
window = tk.Tk()
window.title("ChatBot")
window.geometry("600x500")
window.configure(bg="black")  # Set background color to black

# Load and display an image
image = Image.open("chatbot2_image.jpg")
image = image.resize((100, 100))
photo = ImageTk.PhotoImage(image)
label = tk.Label(window, image=photo, bg="black")  # Set label background color to black
label.pack(pady=10)

# Create a frame for chat history with rounded border
chat_frame = tk.Frame(window, bg="black", highlightbackground="white", highlightthickness=1, padx=5, pady=5)
chat_frame.pack(pady=5)

# Create a scrolled text widget to display the chat history with custom font and colors
chat_history = scrolledtext.ScrolledText(chat_frame, width=45, height=10, wrap=tk.WORD, font=("Arial", 10), bg="black")
chat_history.pack(side=tk.LEFT, fill=tk.BOTH, padx=10, pady=10)
chat_history.tag_config("user", foreground="green")  # Set user's font color to green
chat_history.tag_config("bot", foreground="white")  # Set bot's font color to white

# Create a frame for user input and buttons
input_frame = tk.Frame(window, bg="black")
input_frame.pack(pady=5)

# Create an entry widget for user input with custom font and colors
entry = tk.Entry(input_frame, width=40, font=("Arial", 10), bg="gray", fg="black")
entry.pack(side=tk.LEFT, padx=10)

# Create a button to send the user's message with custom colors
send_button = tk.Button(input_frame, text="Send", width=10, command=send_message, bg="gray", fg="black", relief=tk.FLAT)
send_button.pack(side=tk.LEFT)

# Create a button to clear the response
clear_button = tk.Button(input_frame, text="Clear Response", width=15, command=clear_response, bg="gray", fg="black", relief=tk.FLAT)
clear_button.pack(side=tk.LEFT, padx=5)

# Create a "ChatMe" button
chatme_button = tk.Button(input_frame, text="ChatMe", width=10, command=chat_me, bg="gray", fg="black", relief=tk.FLAT)
chatme_button.pack(side=tk.LEFT)

# Start the Tkinter event loop
window.mainloop()
